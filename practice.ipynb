# %%
# import libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# reading csv files
df =  pd.read_csv('adult.data', sep=",", header=None, skipinitialspace=True)
df2 = pd.read_csv('adult.test', sep=",", header=None, skipinitialspace=True)

df = pd.concat([df, df2])

df = df.sample(frac=1).reset_index(drop=True)

df
# Out:
#        0                 1       2             3   4                      5   \
# 0      40  Self-emp-not-inc  406811  Some-college  10     Married-civ-spouse
# 1      44      Self-emp-inc   79521     Bachelors  13     Married-civ-spouse
# 2      83                 ?  251951       HS-grad   9                Widowed
# 3      36           Private   69481   Prof-school  15     Married-civ-spouse
# 4      20           Private  262749  Some-college  10          Never-married
# ...    ..               ...     ...           ...  ..                    ...
# 48837  41           Private  124692  Some-college  10     Married-civ-spouse
# 48838  40           Private  153799       1st-4th   2  Married-spouse-absent
# 48839  58       Federal-gov  256466       Masters  14     Married-civ-spouse
# 48840  39           Private  144169       HS-grad   9     Married-civ-spouse
# 48841  23           Private  214542  Some-college  10          Never-married
#
# ...

# %%
#Splitting into x and y, this time taking all values...

x = df.iloc[:, :-1]
y = df.iloc[:, 14]

x.columns['Age', 'Working Class', 'Final Weight', 'Education', 'Education-num', 'Marital-status', 'Occupation', 'Relationship', 'Race', 'Sex', 'Capital-Gain', 'Capital-Loss', 'Hours Per Week', 'Native Country']
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In [13], line 6
#       3 x = df.iloc[:, :-1]
#       4 y = df.iloc[:, 14]
# ----> 6 x.columns['Age', 'Working Class', 'Final Weight', 'Education', 'Education-num', 'Marital-status', 'Occupation', 'Relationship', 'Race', 'Sex', 'Capital-Gain', 'Capital-Loss', 'Hours Per Week', 'Native Country']
#
# File c:\Users\Nick\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:5380, in Index.__getitem__(self, key)
#    5377     else:
#    5378         key = np.asarray(key, dtype=bool)
# -> 5380 result = getitem(key)
#    5381 # Because we ruled out integer above, we always get an arraylike here
#    5382 if result.ndim > 1:
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices
